# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
y_hat = pd.read_csv(r'../results/version_2_test_predictions.csv',header=None)
y = pd.read_csv(r'../results/version_2_test_targets.csv', header=None)

# %%
fig = plt.figure(figsize=(10, 5))
plt.plot(y_hat.T)
plt.plot(y.T)
